# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter

# %%
data5 = np.genfromtxt("UoR_Data (6).csv", delimiter =',', skip_header=2, filling_values=np.nan)

# %%
Netradiation = data5[:,15]
Td = data5[:,2]
Tgrass = data5[:,3]
WetBulbT = data5[:,4]
RH = data5[:,5]
Ldw = data5[:,13]
Luw =data5[:,14]
Sdw= data5[:,16]
suw= data5[:,17]
time= data5[:,1]

# %%
SW= (Sdw-suw)
LW= -(Ldw-Luw)
Rn = LW+SW

# %%
plt.plot(SW,"-.",label='Sn',lw=2)
plt.plot(LW,"--",label='Ln',lw=2)

# %%
data31 = np.genfromtxt("UoR_Data (7).csv", delimiter =',', skip_header=66, filling_values=np.nan)

# %%
Rn2 = data31[:,13]
Td2 = data31[:,1]
Tgrass2 = data31[:,2]
WetBulbT2 = data31[:,3]
RH2 = data31[:,4]
Ldw2 = data31[:,11]
Luw2 =data31[:,12]
Sdw2= data31[:,14]
suw2= data31[:,15]
time= data31[:,1]

# %%
print(Tgrass2)
# Out:
# [5.39 5.39 5.42 ...  nan  nan  nan]

# %%
SW2= (Sdw2-suw2)
LW2= -(Ldw2-Luw2)
Rn2 = LW2+SW2

# %%
plt.plot(time ,Tgrass2,label='Grass Temp',lw=2,color='green')
plt.plot(time,Td2,label='Dry bulb Temp',lw=2, color='red')
plt.plot(time,WetBulbT2 ,label='Wet bulb temp',lw=2, color='blue')
plt.ylabel('Temp (degree)')
plt.legend(loc=2)

# %%
plt.plot(RH2)

# %%
plt.plot(SW2,"-.",label='Sn',lw=2)
plt.plot(LW2,"--",label='Ln',lw=2)
