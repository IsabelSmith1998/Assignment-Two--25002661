# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import pandas as pd

# %%
from pathlib import Path

# %%
list(Path().cwd().glob('*xlsx'))
# Out:
# [WindowsPath('C:/Users/kh002661/Documents/Assignmnet-2/UoR_Data-rnm.xlsx')]

# %%
df8 =pd.read_csv("8-10th.csv",header=[0,1],index_col=0)
df8=df8.droplevel(1,axis=1)
df8.index=pd.to_datetime(df8.index)

# %%
df8.columns
# Out:
# Index(['Base1mean', 'Base1min'], dtype='object', name='TimeStamp')

# %%
plt.figure(num=1, figsize=(25,10))
plt.plot(df8.Base1min)
plt.plot(df8.Base1mean)
plt.ylabel('Cloudbase (M)',fontsize=20)
plt.legend(loc='best',fontsize=20)
plt.tick_params(labelsize= 18)
plt.title('Energy Budget on the 31st of October',fontsize=20)
plt.xlabel('Date and Time',fontsize=20)
# Out:
# Text(0.5, 0, 'Date and Time')

# %%
df9 =pd.read_csv("8-10th temp.csv",header=[0,1],index_col=0)
df9=df9.droplevel(1,axis=1)
df9.index=pd.to_datetime(df9.index)

# %%
df9.columns
# Out:
# Index(['Td', 'Tgrass', 'Tw', 'RH', 'Ldw', 'Luw', 'Rn', 'Sdw', 'Suw'], dtype='object', name='TimeStamp')

# %%
SW = df9.Sdw - df9.Suw
LW= df9.Ldw- df9.Luw

# %%
plt.figure(num=1, figsize=(25,10))
plt.plot(SW,"-.",label='Sn',lw=2)
plt.plot(LW,"--",label='Ln',lw=2)
plt.legend(loc='best',fontsize=20)
plt.tick_params(labelsize= 18)
plt.ylabel('W m${^-}{^2}$',fontsize=20)
plt.legend(loc='best',fontsize=20)
plt.tick_params(labelsize= 18)
plt.ylabel('W m${^-}{^2}$',fontsize=20)
plt.title('Energy Budget on the 8-10th',fontsize=20)
plt.xlabel('time (day,Hour)',fontsize=20)
# Out:
# Text(0.5, 0, 'time (day,Hour)')

# %%
plt.figure(num=1, figsize=(15,10))
plt.plot(figsize=(15,200))
plt.plot(df9.Tgrass,marker="<",label='Grass Temp',lw=1,color='green')
plt.plot(df9.Td,marker ='<',label='Dry bulb Temp',lw=1, color='red')
plt.plot(df9.Tw,"-" ,label='Wet bulb temp',lw=1, color='blue')
plt.ylabel('Temp $^\circ$C',fontsize=20)
plt.tick_params(labelsize= 16)
plt.legend(loc=1,fontsize=20)
plt.title('Temp across a general week in October',fontsize=20)
plt.xlabel('Number of Points',fontsize=20)
# Out:
# Text(0.5, 0, 'Number of Points')

# %%
df31 =pd.read_csv("UoR_Data (7).csv",header=[0,1],index_col=0)
df31=df31.droplevel(1,axis=1)
df31.index=pd.to_datetime(df31.index)

# %%
df31.columns
# Out:
# Index(['Td', 'Tgrass', 'Tw', 'RH', 'U1.12', 'U1.6', 'U2', 'U4.48', 'U6.4',
#        'CNR4T', 'Ldw', 'Luw', 'Rn', 'Sdw', 'Suw'],
#       dtype='object', name='TimeStamp')

# %%
SW = df31.Sdw - df31.Suw
LW= df31.Ldw- df31.Luw

# %%
plt.figure(num=1, figsize=(15,10))
plt.plot(SW,"-.",label='Sn',lw=2)
plt.plot(LW,"--",label='Ln',lw=2)
plt.legend(loc='best',fontsize=20)
plt.tick_params(labelsize= 18)
plt.ylabel('W m${^-}{^2}$',fontsize=20)
plt.legend(loc='best',fontsize=20)
plt.tick_params(labelsize= 18)
plt.ylabel('W m${^-}{^2}$',fontsize=20)
plt.title('Energy Budget on the 31st of October',fontsize=20)
plt.xlabel('time (day,Hour)',fontsize=20)
# Out:
# Text(0.5, 0, 'time (day,Hour)')

# %%
plt.figure(num=1, figsize=(15,10))
plt.plot(figsize=(15,200))
plt.plot(Tgrass,marker="<",label='Grass Temp',lw=1,color='green')
plt.plot(Td,marker ='<',label='Dry bulb Temp',lw=1, color='red')
plt.plot(WetBulbT,"-" ,label='Wet bulb temp',lw=1, color='blue')
plt.ylabel('Temp $^\circ$C',fontsize=20)
plt.tick_params(labelsize= 16)
plt.legend(loc=1,fontsize=20)
plt.title('Temp across a general week in October',fontsize=20)
plt.xlabel('Number of Points',fontsize=20)
# Out:
# Text(0.5, 0, 'Number of Points')

# %%
df2 =pd.read_csv("UoR_Data(29).csv",header=[0,1],index_col=0)
df2=df2.droplevel(1,axis=1)
df2.index=pd.to_datetime(df2.index)

# %%
df2.Tsoil.plot()

# %%
SW2= (Sdw2-suw2)
LW2= -(Ldw2-Luw2)
RnOb = SW2+LW2

# %%
plt.figure(num=1, figsize=(15,10))
plt.plot(figsize=(15,200))
plt.plot(Tgrass2,marker="<",label='Grass Temp',lw=1,color='green')
plt.plot(Td2,marker ='<',label='Dry bulb Temp',lw=1, color='red')
plt.plot(WetBulbT2,"-" ,label='Wet bulb temp',lw=1, color='blue')
plt.ylabel('Temp $^\circ$C',fontsize=20)
plt.tick_params(labelsize= 16)
plt.legend(loc=2,fontsize=20)
plt.title('Temp on the 29th of Nov',fontsize=20)
plt.xlabel('Number of Points',fontsize=20)
# Out:
# Text(0.5, 0, 'Number of Points')

# %%
plt.figure(num=1, figsize=(15,10))
plt.plot(SW2,"-.",label='Sn',lw=2)
plt.plot(LW2,"--",label='Ln',lw=2)
plt.plot(Rn2,"-",label='Rn',lw=2)
plt.plot(G,">",label='G',lw=2)
plt.legend(loc='best',fontsize=20)
plt.tick_params(labelsize= 18)
plt.ylabel('W m${^-}{^2}$',fontsize=20)
plt.title('Energy Budget of the 29th of Nov',fontsize=20)
plt.xlabel('Number of Points )',fontsize=20)
# Out:
# Text(0.5, 0, 'Number of Points )')

# %%
#data9 = np.genfromtxt("UoR_Data (9).csv", delimiter =',', skip_header=5, filling_values=np.nan)

# %%
df =pd.read_csv("UoR_Data (9).csv",header=[0,1],index_col=0)
df=df.droplevel(1,axis=1)
df.index=pd.to_datetime(df.index)

# %%
df.Tsoil.plot()

# %%
plt.figure(num=1, figsize=(15,10))
plt.plot(figsize=(15,200))
plt.plot(Tgrass,label='Grass Temp',lw=0.5,color='green')
plt.plot(Td,label='Dry bulb Temp',lw=0.5, color='red')
plt.plot(WetBulbT2,label='Wet bulb temp',lw=0.5, color='blue')
plt.ylabel('Temp $^\circ$C',fontsize=20)
plt.tick_params(labelsize= 16)
plt.legend(loc=2,fontsize=20)
plt.title('Temp 20/12/17',fontsize=20)
plt.xlabel('Number of Points',fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-313497693be2> in <module>
#       1 plt.figure(num=1, figsize=(15,10))
#       2 plt.plot(figsize=(15,200))
# ----> 3 plt.plot(Tgrass,label='Grass Temp',lw=0.5,color='green')
#       4 plt.plot(Td,label='Dry bulb Temp',lw=0.5, color='red')
#       5 plt.plot(WetBulbT2,label='Wet bulb temp',lw=0.5, color='blue')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
plt.figure(num=1, figsize=(15,10))
plt.plot(SW2,"-.",label='Sn',lw=2)
plt.plot(LW2,"--",label='Ln',lw=2)
plt.plot(Rn2,"-",label='Rn',lw=2)
plt.legend(loc='best',fontsize=20)
plt.tick_params(labelsize= 18)
plt.ylabel('W m${^-}{^2}$',fontsize=20)
plt.title('Energy Budget of the 29th of Nov',fontsize=20)
plt.xlabel('Number of Points )',fontsize=20)
# Out:
# Text(0.5, 0, 'Number of Points )')

# %%
data9F = np.genfromtxt("UoR_Data (9)F.csv", delimiter =',', skip_header=2, filling_values=np.nan)

# %%
LE = data9F[:,1]
SH= data9F[:,2]
# Out:
# [-10.779  -3.718  -1.717   4.793  -1.724   0.612  -8.451  20.416     nan
#      nan     nan     nan   2.395  20.523   8.077   4.776  -6.388  23.575
#  -29.765     nan   1.803   9.391  -2.868   6.114  -4.215  13.543  11.001
#    8.37    1.981   1.742   0.776  -0.414  -4.493     nan  -9.298     nan
#      nan   5.833  -3.816  -1.046  -0.108  -1.137   0.295  -8.138   2.367
#   -1.094  -1.716   0.129]

# %%
plt.figure(num=1, figsize=(15,10))
plt.plot(LE,label='Latent Heat',lw=2,color='green')
plt.plot(SH,"-",label='Sensible Heat',lw=2,color='orange')
plt.legend(loc='best',fontsize=20)
plt.tick_params(labelsize= 18)
plt.ylabel('W m${^-}{^2}$',fontsize=20)
plt.title('Energy Budget 20/12/17',fontsize=20)
plt.xlabel('Number of Points )',fontsize=20)
# Out:
# Text(0.5, 0, 'Number of Points )')
